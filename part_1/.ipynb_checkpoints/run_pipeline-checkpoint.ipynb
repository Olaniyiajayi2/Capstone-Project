# %%
# Run this cell to execute the etl.py in part 1
# %run etl.py
# Out:
# ETL pipeline started at 2021-02-01 20:48:48.273322
# Processing Covid19 data...!!!
# Reading in files archive/covid_19_data.csv
# Total time taken to lead data is 0:00:06.444536 ...
# Covid19 data schema:
# root
#  |-- SNo: integer (nullable = true)
#  |-- ObservationDate: timestamp (nullable = true)
#  |-- state: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- lastUpdate: timestamp (nullable = true)
#  |-- Confirmed: double (nullable = true)
#  |-- Deaths: double (nullable = true)
#  |-- Recovered: double (nullable = true)
#
# [INFO]... renaming columns
# Columns renamed
# root
#  |-- SNo: integer (nullable = true)
#  |-- ObservationDate: timestamp (nullable = true)
#  |-- state: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- lastUpdate: timestamp (nullable = true)
#  |-- Confirmed: double (nullable = true)
#  |-- Deaths: double (nullable = true)
#  |-- Recovered: double (nullable = true)
#
# -----------[INFO]--------------
# ...
